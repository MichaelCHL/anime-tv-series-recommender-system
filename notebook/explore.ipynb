# %%
import numpy as np
import pandas as pd
import re

from utils.text_cleaning import stopword_remove, year_conversion

# %%
data = pd.read_csv('../artifacts/raw/anime-dataset-2023.csv')

# %%
data.head(3)
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
#
#        Other name Score                         Genres  \
# 0       カウボーイビバップ  8.75  Action, Award Winning, Sci-Fi
# 1  カウボーイビバップ 天国の扉  8.38                 Action, Sci-Fi
# 2           トライガン  8.22      Action, Adventure, Sci-Fi
#
#                                             Synopsis   Type Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...     TV     26.0
# 1  Another day, another bounty—such is the life o...  Movie      1.0
# 2  Vash the Stampede is the man with a $$60,000,0...     TV     26.0
#
#                          Aired  ...   Studios    Source       Duration  \
# 0  Apr 3, 1998 to Apr 24, 1999  ...   Sunrise  Original  24 min per ep
# ...

# %%
data.shape
# Out:
# (24905, 24)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   anime_id      24905 non-null  int64
#  1   Name          24905 non-null  object
#  2   English name  24905 non-null  object
#  3   Other name    24905 non-null  object
#  4   Score         24905 non-null  object
#  5   Genres        24905 non-null  object
#  6   Synopsis      24905 non-null  object
#  7   Type          24905 non-null  object
#  8   Episodes      24905 non-null  object
#  9   Aired         24905 non-null  object
#  10  Premiered     24905 non-null  object
#  11  Status        24905 non-null  object
#  12  Producers     24905 non-null  object
#  13  Licensors     24905 non-null  object
#  14  Studios       24905 non-null  object
#  15  Source        24905 non-null  object
#  16  Duration      24905 non-null  object
#  17  Rating        24905 non-null  object
# ...

# %%
data['Aired']
# Out:
# 0         Apr 3, 1998 to Apr 24, 1999
# 1                         Sep 1, 2001
# 2         Apr 1, 1998 to Sep 30, 1998
# 3         Jul 3, 2002 to Dec 25, 2002
# 4        Sep 30, 2004 to Sep 29, 2005
#                      ...
# 24900                Jul 4, 2023 to ?
# 24901               Jul 27, 2023 to ?
# 24902               Jul 19, 2023 to ?
# 24903                    Apr 23, 2022
# 24904                     Sep 5, 2022
# Name: Aired, Length: 24905, dtype: object

# %%
data.columns
# Out:
# Index(['anime_id', 'Name', 'English name', 'Other name', 'Score', 'Genres',
#        'Synopsis', 'Type', 'Episodes', 'Aired', 'Premiered', 'Status',
#        'Producers', 'Licensors', 'Studios', 'Source', 'Duration', 'Rating',
#        'Rank', 'Popularity', 'Favorites', 'Scored By', 'Members', 'Image URL'],
#       dtype='object')

# %%
data['year'] = data['Aired'].apply(year_conversion)
data['year']
# Out:
# 0        1998
# 1        2001
# 2        1998
# 3        2002
# 4        2004
#          ...
# 24900    2023
# 24901    2023
# 24902    2023
# 24903    2022
# 24904    2022
# Name: year, Length: 24905, dtype: object

# %%
data['year'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 24905 entries, 0 to 24904
# Series name: year
# Non-Null Count  Dtype
# --------------  -----
# 23990 non-null  object
# dtypes: object(1)
# memory usage: 194.7+ KB

# %%
df = data[['Name', 'English name', 'Score', 'Genres', 'Synopsis', 'Type', 'Episodes', 'Rating', 'Members', 'year']]

# %%
df.head()
# Out:
#                               Name             English name Score  \
# 0                     Cowboy Bebop             Cowboy Bebop  8.75
# 1  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie  8.38
# 2                           Trigun                   Trigun  8.22
# 3               Witch Hunter Robin       Witch Hunter Robin  7.25
# 4                   Bouken Ou Beet   Beet the Vandel Buster  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
#                                             Synopsis   Type Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...     TV     26.0
# 1  Another day, another bounty—such is the life o...  Movie      1.0
# 2  Vash the Stampede is the man with a $$60,000,0...     TV     26.0
# ...

# %%
from similarity.cosine_similarity import SimilarityCalculator

# %%
calculator = SimilarityCalculator('tdf-idf')
calculator.load_model()

# %%
result = calculator.compute()
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# File ~/Desktop/Project/anime-tv-series-recommender-system/src/similarity/cosine_similarity.py:37, in SimilarityCalculator.compute(self)
#      36 logger.info("Calculating similarity...")
# ---> 37 sims = cosine_similarity(self.feature_matrix, self.feature_matrix).flatten()
#      38 logger.info("Calculation completed!")
#
# File ~/opt/anaconda3/envs/anime_env/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:208, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     206 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 208 validate_parameter_constraints(
#     209     parameter_constraints, params, caller_name=func.__qualname__
#     210 )
#     212 try:
#
# ...

# %%
from scipy.sparse import load_npz
from pathlib import Path
from config.path import FEATURE_DIR

matrix_path = FEATURE_DIR / 'tfidf_matrix.npz'
feature_matrix = load_npz(matrix_path)

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity(feature_matrix, feature_matrix)
# Out:
# array([[1.        , 0.29343572, 0.02121748, ..., 0.02052628, 0.        ,
#         0.        ],
#        [0.29343572, 1.        , 0.03319742, ..., 0.0347859 , 0.        ,
#         0.        ],
#        [0.02121748, 0.03319742, 1.        , ..., 0.03491578, 0.        ,
#         0.        ],
#        ...,
#        [0.02052628, 0.0347859 , 0.03491578, ..., 1.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 1.        ,
#         0.36480356],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.36480356,
#         1.        ]], shape=(24905, 24905))
